# %% [markdown]
# # Shufflenet
#
# Implement ShuffleNet by Tensorflow2

# %%
import tensorflow as tf
from tensorflow.keras import Model,layers, Input

# %%
class ConvBNRelu(Model):

    def __init__(self, channels, kernel_size, strides):
        super(ConvBNRelu, self).__init__()
        self.conv = layers.Conv2D(channels, kernel_size, strides, padding='same', use_bias=False)
        self.bn = layers.BatchNormalization()
        self.relu = layers.ReLU()
    
    def __call__(self, inputs, training = True):
        x = self.conv(inputs)
        x = self.bn(x, training)
        x = self.relu(x)
        return x

class DepthwiseConvBNRelu(Model):
    def __init__(self, kernel_size, strides):
        super(DepthwiseConvBNRelu, self).__init__()
        self.depth_wise = layers.DepthwiseConv2D(kernel_size, strides, padding = 'same', use_bias=False)
        self.bn = layers.BatchNormalization()
    
    def __call__(self, inputs, training = True):
        x = self.depth_wise(inputs)
        x =self.bn(x, training)
        return x

class ChannelShuffle(Model):
    def __init__(self, group):
        super(ChannelShuffle, self).__init__()
        self.group = group
    
    def __call__(self, inputs):
        shape = inputs.shape
        # batch = shape[0]
        h = shape[1]
        w = shape[2]
        c = shape[3]
        # assert c % self.group == 0, 'c % group needs to be zero!'

        inputs = tf.reshape(inputs, shape=[-1, h, w, c // self.group, self.group])
        inputs = tf.transpose(inputs, [0, 1, 2, 4, 3])
        inputs = tf.reshape(inputs, shape=(-1, h, w, c))

        return inputs

class ShuffleBlock(Model):
    def __init__(self, channels, strides, split_ratio = 0.5):
        super(ShuffleBlock, self).__init__()
        self.split_ratio = split_ratio
        self.conv1 = ConvBNRelu(channels//2, 1, 1)
        self.depth_wise = DepthwiseConvBNRelu(3, strides = strides)
        self.conv2 = ConvBNRelu(channels//2, 1, 1)
        self.shuffle = ChannelShuffle(group=2)
    
    def __call__(self, inputs, training):
        # channle split
        x1, x2 = tf.split(inputs, num_or_size_splits=int(1/self.split_ratio), axis = -1)
        # conv_1*1 depthwise_3*3 conv1*1
        x2 = self.conv1(x2, training)
        x2 = self.depth_wise(x2, training)
        x2 = self.conv2(x2, training)
        # concatenate x1 and x2 to make information comunicate
        feature = layers.Concatenate()([x1, x2])
        # channel shuffle
        res = self.shuffle(feature)
        return res

class ShuffleConvBlock(Model):

    def __init__(self, in_channels, out_channels, strides):
        super(ShuffleConvBlock, self).__init__()
        self.conv1 = ConvBNRelu(out_channels - in_channels, 1, 1)
        self.depth_wise = DepthwiseConvBNRelu(3, strides=strides)
        self.conv2 = ConvBNRelu(out_channels - in_channels, 1, 1)
        self.depth_wise_lateral = DepthwiseConvBNRelu(3, strides=strides)
        self.conv_lateral = ConvBNRelu(in_channels, 1, 1)
        self.shuffle = ChannelShuffle(group=2)

    def __call__(self, inputs, training):
        x1, x2 = inputs, inputs
        x2 = self.conv1(x2, training)
        x2 = self.depth_wise(x2, training)
        x2 = self.conv2(x2, training)

        x1 = self.depth_wise_lateral(x1, training)
        x1 = self.conv_lateral(x1, training)

        feature = layers.Concatenate()([x1, x2])
        res = self.shuffle(feature)

        return res

class ShuffleNetStage(Model):

    def __init__(self, repeat, in_channels, out_channels):
        super(ShuffleNetStage, self).__init__()
        self.shuffle_conv_block = ShuffleConvBlock(in_channels=in_channels,
                                                   out_channels=out_channels,
                                                   strides=2)
        self.convs = []
        for i in range(repeat):
            self.convs.append(ShuffleBlock(channels=out_channels,
                                           strides=1))

    def __call__(self, inputs, training):
        x = self.shuffle_conv_block(inputs, training)
        for conv in self.convs:
            x = conv(x, training)

        return x

class ShuffleNetV2(Model):
    """ShuffleNetV2
    How to reduce MAC:
    1.make channels_in == channels_out
    2.don't use group convolution
    3.change add to concatenate
    4.don't make model fragmented
    So, use:
    1.conv_1X1
    2.depthwise and pointwise
    3.concatenate rather than add
    4.maybe shuffle block can promote accuracy
    """

    def __init__(self, channels=[24, 116, 232, 464, 1024]):
        super(ShuffleNetV2, self).__init__()
        self.conv1 = layers.Conv2D(channels[0], 3, 2, padding='same')
        self.pool = layers.MaxPool2D(3, strides=2, padding='same')
        self.stage1 = ShuffleNetStage(repeat=3, in_channels=channels[0], out_channels=channels[1])
        self.stage2 = ShuffleNetStage(repeat=7, in_channels=channels[1], out_channels=channels[2])
        self.stage3 = ShuffleNetStage(repeat=3, in_channels=channels[2], out_channels=channels[3])
        self.conv2 = layers.Conv2D(channels[4], kernel_size=1, padding='same')

    def __call__(self, inputs, training):
        x = self.conv1(inputs)
        x = self.pool(x)
        x = self.stage1(x, training)
        x = self.stage2(x, training)
        x = self.stage3(x, training)
        x = self.conv2(x)

        return x

# %%
shufflenet_v2 = ShuffleNetV2()
inputs_ = Input(shape=(224, 224, 3))
res = shufflenet_v2(inputs_, training=True)
model = Model(inputs_, res)
model.summary()
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_17 (InputLayer)           [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d_666 (Conv2D)             (None, 112, 112, 24) 672         input_17[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_77 (MaxPooling2D) (None, 56, 56, 24)   0           conv2d_666[0][0]
# __________________________________________________________________________________________________
# conv2d_667 (Conv2D)             (None, 56, 56, 92)   2208        max_pooling2d_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_380 (BatchN (None, 56, 56, 92)   368         conv2d_667[0][0]
# __________________________________________________________________________________________________
# re_lu_38 (ReLU)                 (None, 56, 56, 92)   0           batch_normalization_380[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_22 (DepthwiseC (None, 28, 28, 24)   216         max_pooling2d_77[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_21 (DepthwiseC (None, 28, 28, 92)   828         re_lu_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_383 (BatchN (None, 28, 28, 24)   96          depthwise_conv2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_381 (BatchN (None, 28, 28, 92)   368         depthwise_conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_669 (Conv2D)             (None, 28, 28, 24)   576         batch_normalization_383[0][0]
# __________________________________________________________________________________________________
# conv2d_668 (Conv2D)             (None, 28, 28, 92)   8464        batch_normalization_381[0][0]
# __________________________________________________________________________________________________
# batch_normalization_384 (BatchN (None, 28, 28, 24)   96          conv2d_669[0][0]
# __________________________________________________________________________________________________
# batch_normalization_382 (BatchN (None, 28, 28, 92)   368         conv2d_668[0][0]
# __________________________________________________________________________________________________
# re_lu_40 (ReLU)                 (None, 28, 28, 24)   0           batch_normalization_384[0][0]
# __________________________________________________________________________________________________
# re_lu_39 (ReLU)                 (None, 28, 28, 92)   0           batch_normalization_382[0][0]
# __________________________________________________________________________________________________
# concatenate_56 (Concatenate)    (None, 28, 28, 116)  0           re_lu_40[0][0]
#                                                                  re_lu_39[0][0]
# __________________________________________________________________________________________________
# tf.reshape_32 (TFOpLambda)      (None, 28, 28, 58, 2 0           concatenate_56[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_16 (TFOp (None, 28, 28, 2, 58 0           tf.reshape_32[0][0]
# __________________________________________________________________________________________________
# tf.reshape_33 (TFOpLambda)      (None, 28, 28, 116)  0           tf.compat.v1.transpose_16[0][0]
# __________________________________________________________________________________________________
# tf.split_13 (TFOpLambda)        [(None, 28, 28, 58), 0           tf.reshape_33[0][0]
# __________________________________________________________________________________________________
# conv2d_670 (Conv2D)             (None, 28, 28, 58)   3364        tf.split_13[0][1]
# __________________________________________________________________________________________________
# batch_normalization_385 (BatchN (None, 28, 28, 58)   232         conv2d_670[0][0]
# __________________________________________________________________________________________________
# re_lu_41 (ReLU)                 (None, 28, 28, 58)   0           batch_normalization_385[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_23 (DepthwiseC (None, 28, 28, 58)   522         re_lu_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_386 (BatchN (None, 28, 28, 58)   232         depthwise_conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_671 (Conv2D)             (None, 28, 28, 58)   3364        batch_normalization_386[0][0]
# __________________________________________________________________________________________________
# batch_normalization_387 (BatchN (None, 28, 28, 58)   232         conv2d_671[0][0]
# __________________________________________________________________________________________________
# re_lu_42 (ReLU)                 (None, 28, 28, 58)   0           batch_normalization_387[0][0]
# __________________________________________________________________________________________________
# concatenate_57 (Concatenate)    (None, 28, 28, 116)  0           tf.split_13[0][0]
#                                                                  re_lu_42[0][0]
# __________________________________________________________________________________________________
# tf.reshape_34 (TFOpLambda)      (None, 28, 28, 58, 2 0           concatenate_57[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_17 (TFOp (None, 28, 28, 2, 58 0           tf.reshape_34[0][0]
# __________________________________________________________________________________________________
# tf.reshape_35 (TFOpLambda)      (None, 28, 28, 116)  0           tf.compat.v1.transpose_17[0][0]
# __________________________________________________________________________________________________
# tf.split_14 (TFOpLambda)        [(None, 28, 28, 58), 0           tf.reshape_35[0][0]
# __________________________________________________________________________________________________
# conv2d_672 (Conv2D)             (None, 28, 28, 58)   3364        tf.split_14[0][1]
# __________________________________________________________________________________________________
# batch_normalization_388 (BatchN (None, 28, 28, 58)   232         conv2d_672[0][0]
# __________________________________________________________________________________________________
# re_lu_43 (ReLU)                 (None, 28, 28, 58)   0           batch_normalization_388[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_24 (DepthwiseC (None, 28, 28, 58)   522         re_lu_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_389 (BatchN (None, 28, 28, 58)   232         depthwise_conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_673 (Conv2D)             (None, 28, 28, 58)   3364        batch_normalization_389[0][0]
# __________________________________________________________________________________________________
# batch_normalization_390 (BatchN (None, 28, 28, 58)   232         conv2d_673[0][0]
# __________________________________________________________________________________________________
# re_lu_44 (ReLU)                 (None, 28, 28, 58)   0           batch_normalization_390[0][0]
# __________________________________________________________________________________________________
# concatenate_58 (Concatenate)    (None, 28, 28, 116)  0           tf.split_14[0][0]
#                                                                  re_lu_44[0][0]
# __________________________________________________________________________________________________
# tf.reshape_36 (TFOpLambda)      (None, 28, 28, 58, 2 0           concatenate_58[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_18 (TFOp (None, 28, 28, 2, 58 0           tf.reshape_36[0][0]
# __________________________________________________________________________________________________
# tf.reshape_37 (TFOpLambda)      (None, 28, 28, 116)  0           tf.compat.v1.transpose_18[0][0]
# __________________________________________________________________________________________________
# tf.split_15 (TFOpLambda)        [(None, 28, 28, 58), 0           tf.reshape_37[0][0]
# __________________________________________________________________________________________________
# conv2d_674 (Conv2D)             (None, 28, 28, 58)   3364        tf.split_15[0][1]
# __________________________________________________________________________________________________
# batch_normalization_391 (BatchN (None, 28, 28, 58)   232         conv2d_674[0][0]
# __________________________________________________________________________________________________
# re_lu_45 (ReLU)                 (None, 28, 28, 58)   0           batch_normalization_391[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_25 (DepthwiseC (None, 28, 28, 58)   522         re_lu_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_392 (BatchN (None, 28, 28, 58)   232         depthwise_conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_675 (Conv2D)             (None, 28, 28, 58)   3364        batch_normalization_392[0][0]
# __________________________________________________________________________________________________
# batch_normalization_393 (BatchN (None, 28, 28, 58)   232         conv2d_675[0][0]
# __________________________________________________________________________________________________
# re_lu_46 (ReLU)                 (None, 28, 28, 58)   0           batch_normalization_393[0][0]
# __________________________________________________________________________________________________
# concatenate_59 (Concatenate)    (None, 28, 28, 116)  0           tf.split_15[0][0]
#                                                                  re_lu_46[0][0]
# __________________________________________________________________________________________________
# tf.reshape_38 (TFOpLambda)      (None, 28, 28, 58, 2 0           concatenate_59[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_19 (TFOp (None, 28, 28, 2, 58 0           tf.reshape_38[0][0]
# __________________________________________________________________________________________________
# tf.reshape_39 (TFOpLambda)      (None, 28, 28, 116)  0           tf.compat.v1.transpose_19[0][0]
# __________________________________________________________________________________________________
# conv2d_676 (Conv2D)             (None, 28, 28, 116)  13456       tf.reshape_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_394 (BatchN (None, 28, 28, 116)  464         conv2d_676[0][0]
# __________________________________________________________________________________________________
# re_lu_47 (ReLU)                 (None, 28, 28, 116)  0           batch_normalization_394[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_27 (DepthwiseC (None, 14, 14, 116)  1044        tf.reshape_39[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_26 (DepthwiseC (None, 14, 14, 116)  1044        re_lu_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_397 (BatchN (None, 14, 14, 116)  464         depthwise_conv2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_395 (BatchN (None, 14, 14, 116)  464         depthwise_conv2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_678 (Conv2D)             (None, 14, 14, 116)  13456       batch_normalization_397[0][0]
# __________________________________________________________________________________________________
# conv2d_677 (Conv2D)             (None, 14, 14, 116)  13456       batch_normalization_395[0][0]
# __________________________________________________________________________________________________
# batch_normalization_398 (BatchN (None, 14, 14, 116)  464         conv2d_678[0][0]
# __________________________________________________________________________________________________
# batch_normalization_396 (BatchN (None, 14, 14, 116)  464         conv2d_677[0][0]
# __________________________________________________________________________________________________
# re_lu_49 (ReLU)                 (None, 14, 14, 116)  0           batch_normalization_398[0][0]
# __________________________________________________________________________________________________
# re_lu_48 (ReLU)                 (None, 14, 14, 116)  0           batch_normalization_396[0][0]
# __________________________________________________________________________________________________
# concatenate_60 (Concatenate)    (None, 14, 14, 232)  0           re_lu_49[0][0]
#                                                                  re_lu_48[0][0]
# __________________________________________________________________________________________________
# tf.reshape_40 (TFOpLambda)      (None, 14, 14, 116,  0           concatenate_60[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_20 (TFOp (None, 14, 14, 2, 11 0           tf.reshape_40[0][0]
# __________________________________________________________________________________________________
# tf.reshape_41 (TFOpLambda)      (None, 14, 14, 232)  0           tf.compat.v1.transpose_20[0][0]
# __________________________________________________________________________________________________
# tf.split_16 (TFOpLambda)        [(None, 14, 14, 116) 0           tf.reshape_41[0][0]
# __________________________________________________________________________________________________
# conv2d_679 (Conv2D)             (None, 14, 14, 116)  13456       tf.split_16[0][1]
# __________________________________________________________________________________________________
# batch_normalization_399 (BatchN (None, 14, 14, 116)  464         conv2d_679[0][0]
# __________________________________________________________________________________________________
# re_lu_50 (ReLU)                 (None, 14, 14, 116)  0           batch_normalization_399[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_28 (DepthwiseC (None, 14, 14, 116)  1044        re_lu_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_400 (BatchN (None, 14, 14, 116)  464         depthwise_conv2d_28[0][0]
# __________________________________________________________________________________________________
# conv2d_680 (Conv2D)             (None, 14, 14, 116)  13456       batch_normalization_400[0][0]
# __________________________________________________________________________________________________
# batch_normalization_401 (BatchN (None, 14, 14, 116)  464         conv2d_680[0][0]
# __________________________________________________________________________________________________
# re_lu_51 (ReLU)                 (None, 14, 14, 116)  0           batch_normalization_401[0][0]
# __________________________________________________________________________________________________
# concatenate_61 (Concatenate)    (None, 14, 14, 232)  0           tf.split_16[0][0]
#                                                                  re_lu_51[0][0]
# __________________________________________________________________________________________________
# tf.reshape_42 (TFOpLambda)      (None, 14, 14, 116,  0           concatenate_61[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_21 (TFOp (None, 14, 14, 2, 11 0           tf.reshape_42[0][0]
# __________________________________________________________________________________________________
# tf.reshape_43 (TFOpLambda)      (None, 14, 14, 232)  0           tf.compat.v1.transpose_21[0][0]
# __________________________________________________________________________________________________
# tf.split_17 (TFOpLambda)        [(None, 14, 14, 116) 0           tf.reshape_43[0][0]
# __________________________________________________________________________________________________
# conv2d_681 (Conv2D)             (None, 14, 14, 116)  13456       tf.split_17[0][1]
# __________________________________________________________________________________________________
# batch_normalization_402 (BatchN (None, 14, 14, 116)  464         conv2d_681[0][0]
# __________________________________________________________________________________________________
# re_lu_52 (ReLU)                 (None, 14, 14, 116)  0           batch_normalization_402[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_29 (DepthwiseC (None, 14, 14, 116)  1044        re_lu_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_403 (BatchN (None, 14, 14, 116)  464         depthwise_conv2d_29[0][0]
# __________________________________________________________________________________________________
# conv2d_682 (Conv2D)             (None, 14, 14, 116)  13456       batch_normalization_403[0][0]
# __________________________________________________________________________________________________
# batch_normalization_404 (BatchN (None, 14, 14, 116)  464         conv2d_682[0][0]
# __________________________________________________________________________________________________
# re_lu_53 (ReLU)                 (None, 14, 14, 116)  0           batch_normalization_404[0][0]
# __________________________________________________________________________________________________
# concatenate_62 (Concatenate)    (None, 14, 14, 232)  0           tf.split_17[0][0]
#                                                                  re_lu_53[0][0]
# __________________________________________________________________________________________________
# tf.reshape_44 (TFOpLambda)      (None, 14, 14, 116,  0           concatenate_62[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_22 (TFOp (None, 14, 14, 2, 11 0           tf.reshape_44[0][0]
# __________________________________________________________________________________________________
# tf.reshape_45 (TFOpLambda)      (None, 14, 14, 232)  0           tf.compat.v1.transpose_22[0][0]
# __________________________________________________________________________________________________
# tf.split_18 (TFOpLambda)        [(None, 14, 14, 116) 0           tf.reshape_45[0][0]
# __________________________________________________________________________________________________
# conv2d_683 (Conv2D)             (None, 14, 14, 116)  13456       tf.split_18[0][1]
# __________________________________________________________________________________________________
# batch_normalization_405 (BatchN (None, 14, 14, 116)  464         conv2d_683[0][0]
# __________________________________________________________________________________________________
# re_lu_54 (ReLU)                 (None, 14, 14, 116)  0           batch_normalization_405[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_30 (DepthwiseC (None, 14, 14, 116)  1044        re_lu_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_406 (BatchN (None, 14, 14, 116)  464         depthwise_conv2d_30[0][0]
# __________________________________________________________________________________________________
# conv2d_684 (Conv2D)             (None, 14, 14, 116)  13456       batch_normalization_406[0][0]
# __________________________________________________________________________________________________
# batch_normalization_407 (BatchN (None, 14, 14, 116)  464         conv2d_684[0][0]
# __________________________________________________________________________________________________
# re_lu_55 (ReLU)                 (None, 14, 14, 116)  0           batch_normalization_407[0][0]
# __________________________________________________________________________________________________
# concatenate_63 (Concatenate)    (None, 14, 14, 232)  0           tf.split_18[0][0]
#                                                                  re_lu_55[0][0]
# __________________________________________________________________________________________________
# tf.reshape_46 (TFOpLambda)      (None, 14, 14, 116,  0           concatenate_63[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_23 (TFOp (None, 14, 14, 2, 11 0           tf.reshape_46[0][0]
# __________________________________________________________________________________________________
# tf.reshape_47 (TFOpLambda)      (None, 14, 14, 232)  0           tf.compat.v1.transpose_23[0][0]
# __________________________________________________________________________________________________
# tf.split_19 (TFOpLambda)        [(None, 14, 14, 116) 0           tf.reshape_47[0][0]
# __________________________________________________________________________________________________
# conv2d_685 (Conv2D)             (None, 14, 14, 116)  13456       tf.split_19[0][1]
# __________________________________________________________________________________________________
# batch_normalization_408 (BatchN (None, 14, 14, 116)  464         conv2d_685[0][0]
# __________________________________________________________________________________________________
# re_lu_56 (ReLU)                 (None, 14, 14, 116)  0           batch_normalization_408[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_31 (DepthwiseC (None, 14, 14, 116)  1044        re_lu_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_409 (BatchN (None, 14, 14, 116)  464         depthwise_conv2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_686 (Conv2D)             (None, 14, 14, 116)  13456       batch_normalization_409[0][0]
# __________________________________________________________________________________________________
# batch_normalization_410 (BatchN (None, 14, 14, 116)  464         conv2d_686[0][0]
# __________________________________________________________________________________________________
# re_lu_57 (ReLU)                 (None, 14, 14, 116)  0           batch_normalization_410[0][0]
# __________________________________________________________________________________________________
# concatenate_64 (Concatenate)    (None, 14, 14, 232)  0           tf.split_19[0][0]
#                                                                  re_lu_57[0][0]
# __________________________________________________________________________________________________
# tf.reshape_48 (TFOpLambda)      (None, 14, 14, 116,  0           concatenate_64[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_24 (TFOp (None, 14, 14, 2, 11 0           tf.reshape_48[0][0]
# __________________________________________________________________________________________________
# tf.reshape_49 (TFOpLambda)      (None, 14, 14, 232)  0           tf.compat.v1.transpose_24[0][0]
# __________________________________________________________________________________________________
# tf.split_20 (TFOpLambda)        [(None, 14, 14, 116) 0           tf.reshape_49[0][0]
# __________________________________________________________________________________________________
# conv2d_687 (Conv2D)             (None, 14, 14, 116)  13456       tf.split_20[0][1]
# __________________________________________________________________________________________________
# batch_normalization_411 (BatchN (None, 14, 14, 116)  464         conv2d_687[0][0]
# __________________________________________________________________________________________________
# re_lu_58 (ReLU)                 (None, 14, 14, 116)  0           batch_normalization_411[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_32 (DepthwiseC (None, 14, 14, 116)  1044        re_lu_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_412 (BatchN (None, 14, 14, 116)  464         depthwise_conv2d_32[0][0]
# __________________________________________________________________________________________________
# conv2d_688 (Conv2D)             (None, 14, 14, 116)  13456       batch_normalization_412[0][0]
# __________________________________________________________________________________________________
# batch_normalization_413 (BatchN (None, 14, 14, 116)  464         conv2d_688[0][0]
# __________________________________________________________________________________________________
# re_lu_59 (ReLU)                 (None, 14, 14, 116)  0           batch_normalization_413[0][0]
# __________________________________________________________________________________________________
# concatenate_65 (Concatenate)    (None, 14, 14, 232)  0           tf.split_20[0][0]
#                                                                  re_lu_59[0][0]
# __________________________________________________________________________________________________
# tf.reshape_50 (TFOpLambda)      (None, 14, 14, 116,  0           concatenate_65[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_25 (TFOp (None, 14, 14, 2, 11 0           tf.reshape_50[0][0]
# __________________________________________________________________________________________________
# tf.reshape_51 (TFOpLambda)      (None, 14, 14, 232)  0           tf.compat.v1.transpose_25[0][0]
# __________________________________________________________________________________________________
# tf.split_21 (TFOpLambda)        [(None, 14, 14, 116) 0           tf.reshape_51[0][0]
# __________________________________________________________________________________________________
# conv2d_689 (Conv2D)             (None, 14, 14, 116)  13456       tf.split_21[0][1]
# __________________________________________________________________________________________________
# batch_normalization_414 (BatchN (None, 14, 14, 116)  464         conv2d_689[0][0]
# __________________________________________________________________________________________________
# re_lu_60 (ReLU)                 (None, 14, 14, 116)  0           batch_normalization_414[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_33 (DepthwiseC (None, 14, 14, 116)  1044        re_lu_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_415 (BatchN (None, 14, 14, 116)  464         depthwise_conv2d_33[0][0]
# __________________________________________________________________________________________________
# conv2d_690 (Conv2D)             (None, 14, 14, 116)  13456       batch_normalization_415[0][0]
# __________________________________________________________________________________________________
# batch_normalization_416 (BatchN (None, 14, 14, 116)  464         conv2d_690[0][0]
# __________________________________________________________________________________________________
# re_lu_61 (ReLU)                 (None, 14, 14, 116)  0           batch_normalization_416[0][0]
# __________________________________________________________________________________________________
# concatenate_66 (Concatenate)    (None, 14, 14, 232)  0           tf.split_21[0][0]
#                                                                  re_lu_61[0][0]
# __________________________________________________________________________________________________
# tf.reshape_52 (TFOpLambda)      (None, 14, 14, 116,  0           concatenate_66[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_26 (TFOp (None, 14, 14, 2, 11 0           tf.reshape_52[0][0]
# __________________________________________________________________________________________________
# tf.reshape_53 (TFOpLambda)      (None, 14, 14, 232)  0           tf.compat.v1.transpose_26[0][0]
# __________________________________________________________________________________________________
# tf.split_22 (TFOpLambda)        [(None, 14, 14, 116) 0           tf.reshape_53[0][0]
# __________________________________________________________________________________________________
# conv2d_691 (Conv2D)             (None, 14, 14, 116)  13456       tf.split_22[0][1]
# __________________________________________________________________________________________________
# batch_normalization_417 (BatchN (None, 14, 14, 116)  464         conv2d_691[0][0]
# __________________________________________________________________________________________________
# re_lu_62 (ReLU)                 (None, 14, 14, 116)  0           batch_normalization_417[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_34 (DepthwiseC (None, 14, 14, 116)  1044        re_lu_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_418 (BatchN (None, 14, 14, 116)  464         depthwise_conv2d_34[0][0]
# __________________________________________________________________________________________________
# conv2d_692 (Conv2D)             (None, 14, 14, 116)  13456       batch_normalization_418[0][0]
# __________________________________________________________________________________________________
# batch_normalization_419 (BatchN (None, 14, 14, 116)  464         conv2d_692[0][0]
# __________________________________________________________________________________________________
# re_lu_63 (ReLU)                 (None, 14, 14, 116)  0           batch_normalization_419[0][0]
# __________________________________________________________________________________________________
# concatenate_67 (Concatenate)    (None, 14, 14, 232)  0           tf.split_22[0][0]
#                                                                  re_lu_63[0][0]
# __________________________________________________________________________________________________
# tf.reshape_54 (TFOpLambda)      (None, 14, 14, 116,  0           concatenate_67[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_27 (TFOp (None, 14, 14, 2, 11 0           tf.reshape_54[0][0]
# __________________________________________________________________________________________________
# tf.reshape_55 (TFOpLambda)      (None, 14, 14, 232)  0           tf.compat.v1.transpose_27[0][0]
# __________________________________________________________________________________________________
# conv2d_693 (Conv2D)             (None, 14, 14, 232)  53824       tf.reshape_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_420 (BatchN (None, 14, 14, 232)  928         conv2d_693[0][0]
# __________________________________________________________________________________________________
# re_lu_64 (ReLU)                 (None, 14, 14, 232)  0           batch_normalization_420[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_36 (DepthwiseC (None, 7, 7, 232)    2088        tf.reshape_55[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_35 (DepthwiseC (None, 7, 7, 232)    2088        re_lu_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_423 (BatchN (None, 7, 7, 232)    928         depthwise_conv2d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_421 (BatchN (None, 7, 7, 232)    928         depthwise_conv2d_35[0][0]
# __________________________________________________________________________________________________
# conv2d_695 (Conv2D)             (None, 7, 7, 232)    53824       batch_normalization_423[0][0]
# __________________________________________________________________________________________________
# conv2d_694 (Conv2D)             (None, 7, 7, 232)    53824       batch_normalization_421[0][0]
# __________________________________________________________________________________________________
# batch_normalization_424 (BatchN (None, 7, 7, 232)    928         conv2d_695[0][0]
# __________________________________________________________________________________________________
# batch_normalization_422 (BatchN (None, 7, 7, 232)    928         conv2d_694[0][0]
# __________________________________________________________________________________________________
# re_lu_66 (ReLU)                 (None, 7, 7, 232)    0           batch_normalization_424[0][0]
# __________________________________________________________________________________________________
# re_lu_65 (ReLU)                 (None, 7, 7, 232)    0           batch_normalization_422[0][0]
# __________________________________________________________________________________________________
# concatenate_68 (Concatenate)    (None, 7, 7, 464)    0           re_lu_66[0][0]
#                                                                  re_lu_65[0][0]
# __________________________________________________________________________________________________
# tf.reshape_56 (TFOpLambda)      (None, 7, 7, 232, 2) 0           concatenate_68[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_28 (TFOp (None, 7, 7, 2, 232) 0           tf.reshape_56[0][0]
# __________________________________________________________________________________________________
# tf.reshape_57 (TFOpLambda)      (None, 7, 7, 464)    0           tf.compat.v1.transpose_28[0][0]
# __________________________________________________________________________________________________
# tf.split_23 (TFOpLambda)        [(None, 7, 7, 232),  0           tf.reshape_57[0][0]
# __________________________________________________________________________________________________
# conv2d_696 (Conv2D)             (None, 7, 7, 232)    53824       tf.split_23[0][1]
# __________________________________________________________________________________________________
# batch_normalization_425 (BatchN (None, 7, 7, 232)    928         conv2d_696[0][0]
# __________________________________________________________________________________________________
# re_lu_67 (ReLU)                 (None, 7, 7, 232)    0           batch_normalization_425[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_37 (DepthwiseC (None, 7, 7, 232)    2088        re_lu_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_426 (BatchN (None, 7, 7, 232)    928         depthwise_conv2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_697 (Conv2D)             (None, 7, 7, 232)    53824       batch_normalization_426[0][0]
# __________________________________________________________________________________________________
# batch_normalization_427 (BatchN (None, 7, 7, 232)    928         conv2d_697[0][0]
# __________________________________________________________________________________________________
# re_lu_68 (ReLU)                 (None, 7, 7, 232)    0           batch_normalization_427[0][0]
# __________________________________________________________________________________________________
# concatenate_69 (Concatenate)    (None, 7, 7, 464)    0           tf.split_23[0][0]
#                                                                  re_lu_68[0][0]
# __________________________________________________________________________________________________
# tf.reshape_58 (TFOpLambda)      (None, 7, 7, 232, 2) 0           concatenate_69[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_29 (TFOp (None, 7, 7, 2, 232) 0           tf.reshape_58[0][0]
# __________________________________________________________________________________________________
# tf.reshape_59 (TFOpLambda)      (None, 7, 7, 464)    0           tf.compat.v1.transpose_29[0][0]
# __________________________________________________________________________________________________
# tf.split_24 (TFOpLambda)        [(None, 7, 7, 232),  0           tf.reshape_59[0][0]
# __________________________________________________________________________________________________
# conv2d_698 (Conv2D)             (None, 7, 7, 232)    53824       tf.split_24[0][1]
# __________________________________________________________________________________________________
# batch_normalization_428 (BatchN (None, 7, 7, 232)    928         conv2d_698[0][0]
# __________________________________________________________________________________________________
# re_lu_69 (ReLU)                 (None, 7, 7, 232)    0           batch_normalization_428[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_38 (DepthwiseC (None, 7, 7, 232)    2088        re_lu_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_429 (BatchN (None, 7, 7, 232)    928         depthwise_conv2d_38[0][0]
# __________________________________________________________________________________________________
# conv2d_699 (Conv2D)             (None, 7, 7, 232)    53824       batch_normalization_429[0][0]
# __________________________________________________________________________________________________
# batch_normalization_430 (BatchN (None, 7, 7, 232)    928         conv2d_699[0][0]
# __________________________________________________________________________________________________
# re_lu_70 (ReLU)                 (None, 7, 7, 232)    0           batch_normalization_430[0][0]
# __________________________________________________________________________________________________
# concatenate_70 (Concatenate)    (None, 7, 7, 464)    0           tf.split_24[0][0]
#                                                                  re_lu_70[0][0]
# __________________________________________________________________________________________________
# tf.reshape_60 (TFOpLambda)      (None, 7, 7, 232, 2) 0           concatenate_70[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_30 (TFOp (None, 7, 7, 2, 232) 0           tf.reshape_60[0][0]
# __________________________________________________________________________________________________
# tf.reshape_61 (TFOpLambda)      (None, 7, 7, 464)    0           tf.compat.v1.transpose_30[0][0]
# __________________________________________________________________________________________________
# tf.split_25 (TFOpLambda)        [(None, 7, 7, 232),  0           tf.reshape_61[0][0]
# __________________________________________________________________________________________________
# conv2d_700 (Conv2D)             (None, 7, 7, 232)    53824       tf.split_25[0][1]
# __________________________________________________________________________________________________
# batch_normalization_431 (BatchN (None, 7, 7, 232)    928         conv2d_700[0][0]
# __________________________________________________________________________________________________
# re_lu_71 (ReLU)                 (None, 7, 7, 232)    0           batch_normalization_431[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_39 (DepthwiseC (None, 7, 7, 232)    2088        re_lu_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_432 (BatchN (None, 7, 7, 232)    928         depthwise_conv2d_39[0][0]
# __________________________________________________________________________________________________
# conv2d_701 (Conv2D)             (None, 7, 7, 232)    53824       batch_normalization_432[0][0]
# __________________________________________________________________________________________________
# batch_normalization_433 (BatchN (None, 7, 7, 232)    928         conv2d_701[0][0]
# __________________________________________________________________________________________________
# re_lu_72 (ReLU)                 (None, 7, 7, 232)    0           batch_normalization_433[0][0]
# __________________________________________________________________________________________________
# concatenate_71 (Concatenate)    (None, 7, 7, 464)    0           tf.split_25[0][0]
#                                                                  re_lu_72[0][0]
# __________________________________________________________________________________________________
# tf.reshape_62 (TFOpLambda)      (None, 7, 7, 232, 2) 0           concatenate_71[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_31 (TFOp (None, 7, 7, 2, 232) 0           tf.reshape_62[0][0]
# __________________________________________________________________________________________________
# tf.reshape_63 (TFOpLambda)      (None, 7, 7, 464)    0           tf.compat.v1.transpose_31[0][0]
# __________________________________________________________________________________________________
# conv2d_702 (Conv2D)             (None, 7, 7, 1024)   476160      tf.reshape_63[0][0]
# ==================================================================================================
# Total params: 1,272,318
# Trainable params: 1,258,098
# Non-trainable params: 14,220
# __________________________________________________________________________________________________

# %% [markdown]
# # SqueezeNet
#
# Implement SqueezeNet by Tensorflow2

# %%
import tensorflow as tf
from tensorflow.keras import Input, Model, layers

class Mish(layers.Layer):
    def __init__(self):
        super(Mish, self).__init__()

    def __call__(self, inputs):
        return tf.multiply(inputs, tf.tanh(tf.nn.softplus(inputs)))

class FireBlock(layers.Layer):

    def __init__(self, filter1, filter2, filter3):
        super(FireBlock, self).__init__()
        self.conv1 = layers.Conv2D(filters=filter1, kernel_size=1, padding='same', use_bias=False)
        self.conv2 = layers.Conv2D(filters=filter2, kernel_size=1, padding='same', use_bias=False)
        self.conv3 = layers.Conv2D(filters=filter3, kernel_size=3, padding='same', use_bias=False)
        self.bn1 = layers.BatchNormalization()
        self.bn2 = layers.BatchNormalization()
        self.bn3 = layers.BatchNormalization()

    def __call__(self, inputs):
        squeeze_x = self.conv1(inputs)
        squeeze_x = self.bn1(squeeze_x)
        squeeze_x = Mish()(squeeze_x)
        expand_x1 = self.conv2(squeeze_x)
        expand_x1 = self.bn2(expand_x1)
        expand_x1 = Mish()(expand_x1)
        expand_x3 = self.conv3(squeeze_x)
        expand_x3 = self.bn3(expand_x3)
        expand_x3 = Mish()(expand_x3)

        merge_x = layers.Concatenate()([expand_x1, expand_x3])

        return merge_x

class SqueezeNet(Model):
    def __init__(self):
        super(SqueezeNet, self).__init__()
        self.conv1 = layers.Conv2D(filters=96, kernel_size=7, strides=2, padding='same', use_bias=False)
        self.bn1 = layers.BatchNormalization()
        self.act1 = Mish()
        self.pool1 = layers.MaxPool2D(3, strides=2, padding='same')
        self.fire_block2 = FireBlock(16, 64, 64)
        self.fire_block3 = FireBlock(16, 64, 64)
        self.fire_block4 = FireBlock(32, 128, 128)
        self.pool4 = layers.MaxPool2D(3, strides=2, padding='same')
        self.fire_block5 = FireBlock(32, 128, 128)
        self.fire_block6 = FireBlock(48, 192, 192)
        self.fire_block7 = FireBlock(48, 192, 192)
        self.fire_block8 = FireBlock(64, 256, 256)
        self.pool8 = layers.MaxPool2D(3, strides=2, padding='same')
        self.fire_block9 = FireBlock(64, 256, 256)
    
    def __call__(self, inputs = None):
        if not inputs:
            inputs = Input(shape=(224, 224, 3))
        x = self.conv1(inputs)
        x = self.bn1(x)
        x = self.act1(x)
        x = self.pool1(x)
        x = self.fire_block2(x)
        x = self.fire_block3(x)
        x = self.fire_block4(x)
        x = self.pool4(x)
        x = self.fire_block5(x)
        x = self.fire_block6(x)
        x = self.fire_block7(x)
        x = self.fire_block8(x)
        x = self.pool8(x)
        x = self.fire_block9(x)
        squeeze = Model(inputs, x)
        return squeeze
squeeze_net = SqueezeNet()
model = squeeze_net()
model.summary()
# Out:
# Model: "model_9"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_20 (InputLayer)           [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d_753 (Conv2D)             (None, 112, 112, 96) 14112       input_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_484 (BatchN (None, 112, 112, 96) 384         conv2d_753[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_189 (TFOpLambd (None, 112, 112, 96) 0           batch_normalization_484[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_189 (TFOpLambda)   (None, 112, 112, 96) 0           tf.math.softplus_189[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_189 (TFOpLambd (None, 112, 112, 96) 0           batch_normalization_484[0][0]
#                                                                  tf.math.tanh_189[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_84 (MaxPooling2D) (None, 56, 56, 96)   0           tf.math.multiply_189[0][0]
# __________________________________________________________________________________________________
# conv2d_754 (Conv2D)             (None, 56, 56, 16)   1536        max_pooling2d_84[0][0]
# __________________________________________________________________________________________________
# batch_normalization_485 (BatchN (None, 56, 56, 16)   64          conv2d_754[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_190 (TFOpLambd (None, 56, 56, 16)   0           batch_normalization_485[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_190 (TFOpLambda)   (None, 56, 56, 16)   0           tf.math.softplus_190[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_190 (TFOpLambd (None, 56, 56, 16)   0           batch_normalization_485[0][0]
#                                                                  tf.math.tanh_190[0][0]
# __________________________________________________________________________________________________
# conv2d_755 (Conv2D)             (None, 56, 56, 64)   1024        tf.math.multiply_190[0][0]
# __________________________________________________________________________________________________
# conv2d_756 (Conv2D)             (None, 56, 56, 64)   9216        tf.math.multiply_190[0][0]
# __________________________________________________________________________________________________
# batch_normalization_486 (BatchN (None, 56, 56, 64)   256         conv2d_755[0][0]
# __________________________________________________________________________________________________
# batch_normalization_487 (BatchN (None, 56, 56, 64)   256         conv2d_756[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_191 (TFOpLambd (None, 56, 56, 64)   0           batch_normalization_486[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_192 (TFOpLambd (None, 56, 56, 64)   0           batch_normalization_487[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_191 (TFOpLambda)   (None, 56, 56, 64)   0           tf.math.softplus_191[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_192 (TFOpLambda)   (None, 56, 56, 64)   0           tf.math.softplus_192[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_191 (TFOpLambd (None, 56, 56, 64)   0           batch_normalization_486[0][0]
#                                                                  tf.math.tanh_191[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_192 (TFOpLambd (None, 56, 56, 64)   0           batch_normalization_487[0][0]
#                                                                  tf.math.tanh_192[0][0]
# __________________________________________________________________________________________________
# concatenate_88 (Concatenate)    (None, 56, 56, 128)  0           tf.math.multiply_191[0][0]
#                                                                  tf.math.multiply_192[0][0]
# __________________________________________________________________________________________________
# conv2d_757 (Conv2D)             (None, 56, 56, 16)   2048        concatenate_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_488 (BatchN (None, 56, 56, 16)   64          conv2d_757[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_193 (TFOpLambd (None, 56, 56, 16)   0           batch_normalization_488[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_193 (TFOpLambda)   (None, 56, 56, 16)   0           tf.math.softplus_193[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_193 (TFOpLambd (None, 56, 56, 16)   0           batch_normalization_488[0][0]
#                                                                  tf.math.tanh_193[0][0]
# __________________________________________________________________________________________________
# conv2d_758 (Conv2D)             (None, 56, 56, 64)   1024        tf.math.multiply_193[0][0]
# __________________________________________________________________________________________________
# conv2d_759 (Conv2D)             (None, 56, 56, 64)   9216        tf.math.multiply_193[0][0]
# __________________________________________________________________________________________________
# batch_normalization_489 (BatchN (None, 56, 56, 64)   256         conv2d_758[0][0]
# __________________________________________________________________________________________________
# batch_normalization_490 (BatchN (None, 56, 56, 64)   256         conv2d_759[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_194 (TFOpLambd (None, 56, 56, 64)   0           batch_normalization_489[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_195 (TFOpLambd (None, 56, 56, 64)   0           batch_normalization_490[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_194 (TFOpLambda)   (None, 56, 56, 64)   0           tf.math.softplus_194[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_195 (TFOpLambda)   (None, 56, 56, 64)   0           tf.math.softplus_195[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_194 (TFOpLambd (None, 56, 56, 64)   0           batch_normalization_489[0][0]
#                                                                  tf.math.tanh_194[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_195 (TFOpLambd (None, 56, 56, 64)   0           batch_normalization_490[0][0]
#                                                                  tf.math.tanh_195[0][0]
# __________________________________________________________________________________________________
# concatenate_89 (Concatenate)    (None, 56, 56, 128)  0           tf.math.multiply_194[0][0]
#                                                                  tf.math.multiply_195[0][0]
# __________________________________________________________________________________________________
# conv2d_760 (Conv2D)             (None, 56, 56, 32)   4096        concatenate_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_491 (BatchN (None, 56, 56, 32)   128         conv2d_760[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_196 (TFOpLambd (None, 56, 56, 32)   0           batch_normalization_491[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_196 (TFOpLambda)   (None, 56, 56, 32)   0           tf.math.softplus_196[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_196 (TFOpLambd (None, 56, 56, 32)   0           batch_normalization_491[0][0]
#                                                                  tf.math.tanh_196[0][0]
# __________________________________________________________________________________________________
# conv2d_761 (Conv2D)             (None, 56, 56, 128)  4096        tf.math.multiply_196[0][0]
# __________________________________________________________________________________________________
# conv2d_762 (Conv2D)             (None, 56, 56, 128)  36864       tf.math.multiply_196[0][0]
# __________________________________________________________________________________________________
# batch_normalization_492 (BatchN (None, 56, 56, 128)  512         conv2d_761[0][0]
# __________________________________________________________________________________________________
# batch_normalization_493 (BatchN (None, 56, 56, 128)  512         conv2d_762[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_197 (TFOpLambd (None, 56, 56, 128)  0           batch_normalization_492[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_198 (TFOpLambd (None, 56, 56, 128)  0           batch_normalization_493[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_197 (TFOpLambda)   (None, 56, 56, 128)  0           tf.math.softplus_197[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_198 (TFOpLambda)   (None, 56, 56, 128)  0           tf.math.softplus_198[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_197 (TFOpLambd (None, 56, 56, 128)  0           batch_normalization_492[0][0]
#                                                                  tf.math.tanh_197[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_198 (TFOpLambd (None, 56, 56, 128)  0           batch_normalization_493[0][0]
#                                                                  tf.math.tanh_198[0][0]
# __________________________________________________________________________________________________
# concatenate_90 (Concatenate)    (None, 56, 56, 256)  0           tf.math.multiply_197[0][0]
#                                                                  tf.math.multiply_198[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_85 (MaxPooling2D) (None, 28, 28, 256)  0           concatenate_90[0][0]
# __________________________________________________________________________________________________
# conv2d_763 (Conv2D)             (None, 28, 28, 32)   8192        max_pooling2d_85[0][0]
# __________________________________________________________________________________________________
# batch_normalization_494 (BatchN (None, 28, 28, 32)   128         conv2d_763[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_199 (TFOpLambd (None, 28, 28, 32)   0           batch_normalization_494[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_199 (TFOpLambda)   (None, 28, 28, 32)   0           tf.math.softplus_199[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_199 (TFOpLambd (None, 28, 28, 32)   0           batch_normalization_494[0][0]
#                                                                  tf.math.tanh_199[0][0]
# __________________________________________________________________________________________________
# conv2d_764 (Conv2D)             (None, 28, 28, 128)  4096        tf.math.multiply_199[0][0]
# __________________________________________________________________________________________________
# conv2d_765 (Conv2D)             (None, 28, 28, 128)  36864       tf.math.multiply_199[0][0]
# __________________________________________________________________________________________________
# batch_normalization_495 (BatchN (None, 28, 28, 128)  512         conv2d_764[0][0]
# __________________________________________________________________________________________________
# batch_normalization_496 (BatchN (None, 28, 28, 128)  512         conv2d_765[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_200 (TFOpLambd (None, 28, 28, 128)  0           batch_normalization_495[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_201 (TFOpLambd (None, 28, 28, 128)  0           batch_normalization_496[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_200 (TFOpLambda)   (None, 28, 28, 128)  0           tf.math.softplus_200[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_201 (TFOpLambda)   (None, 28, 28, 128)  0           tf.math.softplus_201[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_200 (TFOpLambd (None, 28, 28, 128)  0           batch_normalization_495[0][0]
#                                                                  tf.math.tanh_200[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_201 (TFOpLambd (None, 28, 28, 128)  0           batch_normalization_496[0][0]
#                                                                  tf.math.tanh_201[0][0]
# __________________________________________________________________________________________________
# concatenate_91 (Concatenate)    (None, 28, 28, 256)  0           tf.math.multiply_200[0][0]
#                                                                  tf.math.multiply_201[0][0]
# __________________________________________________________________________________________________
# conv2d_766 (Conv2D)             (None, 28, 28, 48)   12288       concatenate_91[0][0]
# __________________________________________________________________________________________________
# batch_normalization_497 (BatchN (None, 28, 28, 48)   192         conv2d_766[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_202 (TFOpLambd (None, 28, 28, 48)   0           batch_normalization_497[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_202 (TFOpLambda)   (None, 28, 28, 48)   0           tf.math.softplus_202[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_202 (TFOpLambd (None, 28, 28, 48)   0           batch_normalization_497[0][0]
#                                                                  tf.math.tanh_202[0][0]
# __________________________________________________________________________________________________
# conv2d_767 (Conv2D)             (None, 28, 28, 192)  9216        tf.math.multiply_202[0][0]
# __________________________________________________________________________________________________
# conv2d_768 (Conv2D)             (None, 28, 28, 192)  82944       tf.math.multiply_202[0][0]
# __________________________________________________________________________________________________
# batch_normalization_498 (BatchN (None, 28, 28, 192)  768         conv2d_767[0][0]
# __________________________________________________________________________________________________
# batch_normalization_499 (BatchN (None, 28, 28, 192)  768         conv2d_768[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_203 (TFOpLambd (None, 28, 28, 192)  0           batch_normalization_498[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_204 (TFOpLambd (None, 28, 28, 192)  0           batch_normalization_499[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_203 (TFOpLambda)   (None, 28, 28, 192)  0           tf.math.softplus_203[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_204 (TFOpLambda)   (None, 28, 28, 192)  0           tf.math.softplus_204[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_203 (TFOpLambd (None, 28, 28, 192)  0           batch_normalization_498[0][0]
#                                                                  tf.math.tanh_203[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_204 (TFOpLambd (None, 28, 28, 192)  0           batch_normalization_499[0][0]
#                                                                  tf.math.tanh_204[0][0]
# __________________________________________________________________________________________________
# concatenate_92 (Concatenate)    (None, 28, 28, 384)  0           tf.math.multiply_203[0][0]
#                                                                  tf.math.multiply_204[0][0]
# __________________________________________________________________________________________________
# conv2d_769 (Conv2D)             (None, 28, 28, 48)   18432       concatenate_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_500 (BatchN (None, 28, 28, 48)   192         conv2d_769[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_205 (TFOpLambd (None, 28, 28, 48)   0           batch_normalization_500[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_205 (TFOpLambda)   (None, 28, 28, 48)   0           tf.math.softplus_205[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_205 (TFOpLambd (None, 28, 28, 48)   0           batch_normalization_500[0][0]
#                                                                  tf.math.tanh_205[0][0]
# __________________________________________________________________________________________________
# conv2d_770 (Conv2D)             (None, 28, 28, 192)  9216        tf.math.multiply_205[0][0]
# __________________________________________________________________________________________________
# conv2d_771 (Conv2D)             (None, 28, 28, 192)  82944       tf.math.multiply_205[0][0]
# __________________________________________________________________________________________________
# batch_normalization_501 (BatchN (None, 28, 28, 192)  768         conv2d_770[0][0]
# __________________________________________________________________________________________________
# batch_normalization_502 (BatchN (None, 28, 28, 192)  768         conv2d_771[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_206 (TFOpLambd (None, 28, 28, 192)  0           batch_normalization_501[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_207 (TFOpLambd (None, 28, 28, 192)  0           batch_normalization_502[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_206 (TFOpLambda)   (None, 28, 28, 192)  0           tf.math.softplus_206[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_207 (TFOpLambda)   (None, 28, 28, 192)  0           tf.math.softplus_207[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_206 (TFOpLambd (None, 28, 28, 192)  0           batch_normalization_501[0][0]
#                                                                  tf.math.tanh_206[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_207 (TFOpLambd (None, 28, 28, 192)  0           batch_normalization_502[0][0]
#                                                                  tf.math.tanh_207[0][0]
# __________________________________________________________________________________________________
# concatenate_93 (Concatenate)    (None, 28, 28, 384)  0           tf.math.multiply_206[0][0]
#                                                                  tf.math.multiply_207[0][0]
# __________________________________________________________________________________________________
# conv2d_772 (Conv2D)             (None, 28, 28, 64)   24576       concatenate_93[0][0]
# __________________________________________________________________________________________________
# batch_normalization_503 (BatchN (None, 28, 28, 64)   256         conv2d_772[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_208 (TFOpLambd (None, 28, 28, 64)   0           batch_normalization_503[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_208 (TFOpLambda)   (None, 28, 28, 64)   0           tf.math.softplus_208[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_208 (TFOpLambd (None, 28, 28, 64)   0           batch_normalization_503[0][0]
#                                                                  tf.math.tanh_208[0][0]
# __________________________________________________________________________________________________
# conv2d_773 (Conv2D)             (None, 28, 28, 256)  16384       tf.math.multiply_208[0][0]
# __________________________________________________________________________________________________
# conv2d_774 (Conv2D)             (None, 28, 28, 256)  147456      tf.math.multiply_208[0][0]
# __________________________________________________________________________________________________
# batch_normalization_504 (BatchN (None, 28, 28, 256)  1024        conv2d_773[0][0]
# __________________________________________________________________________________________________
# batch_normalization_505 (BatchN (None, 28, 28, 256)  1024        conv2d_774[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_209 (TFOpLambd (None, 28, 28, 256)  0           batch_normalization_504[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_210 (TFOpLambd (None, 28, 28, 256)  0           batch_normalization_505[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_209 (TFOpLambda)   (None, 28, 28, 256)  0           tf.math.softplus_209[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_210 (TFOpLambda)   (None, 28, 28, 256)  0           tf.math.softplus_210[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_209 (TFOpLambd (None, 28, 28, 256)  0           batch_normalization_504[0][0]
#                                                                  tf.math.tanh_209[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_210 (TFOpLambd (None, 28, 28, 256)  0           batch_normalization_505[0][0]
#                                                                  tf.math.tanh_210[0][0]
# __________________________________________________________________________________________________
# concatenate_94 (Concatenate)    (None, 28, 28, 512)  0           tf.math.multiply_209[0][0]
#                                                                  tf.math.multiply_210[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_86 (MaxPooling2D) (None, 14, 14, 512)  0           concatenate_94[0][0]
# __________________________________________________________________________________________________
# conv2d_775 (Conv2D)             (None, 14, 14, 64)   32768       max_pooling2d_86[0][0]
# __________________________________________________________________________________________________
# batch_normalization_506 (BatchN (None, 14, 14, 64)   256         conv2d_775[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_211 (TFOpLambd (None, 14, 14, 64)   0           batch_normalization_506[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_211 (TFOpLambda)   (None, 14, 14, 64)   0           tf.math.softplus_211[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_211 (TFOpLambd (None, 14, 14, 64)   0           batch_normalization_506[0][0]
#                                                                  tf.math.tanh_211[0][0]
# __________________________________________________________________________________________________
# conv2d_776 (Conv2D)             (None, 14, 14, 256)  16384       tf.math.multiply_211[0][0]
# __________________________________________________________________________________________________
# conv2d_777 (Conv2D)             (None, 14, 14, 256)  147456      tf.math.multiply_211[0][0]
# __________________________________________________________________________________________________
# batch_normalization_507 (BatchN (None, 14, 14, 256)  1024        conv2d_776[0][0]
# __________________________________________________________________________________________________
# batch_normalization_508 (BatchN (None, 14, 14, 256)  1024        conv2d_777[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_212 (TFOpLambd (None, 14, 14, 256)  0           batch_normalization_507[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_213 (TFOpLambd (None, 14, 14, 256)  0           batch_normalization_508[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_212 (TFOpLambda)   (None, 14, 14, 256)  0           tf.math.softplus_212[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_213 (TFOpLambda)   (None, 14, 14, 256)  0           tf.math.softplus_213[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_212 (TFOpLambd (None, 14, 14, 256)  0           batch_normalization_507[0][0]
#                                                                  tf.math.tanh_212[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_213 (TFOpLambd (None, 14, 14, 256)  0           batch_normalization_508[0][0]
#                                                                  tf.math.tanh_213[0][0]
# __________________________________________________________________________________________________
# concatenate_95 (Concatenate)    (None, 14, 14, 512)  0           tf.math.multiply_212[0][0]
#                                                                  tf.math.multiply_213[0][0]
# ==================================================================================================
# Total params: 744,352
# Trainable params: 738,400
# Non-trainable params: 5,952
# __________________________________________________________________________________________________

# %%
squeeze_net = SqueezeNet()
model = squeeze_net()
model.summary()
# Out:
# Model: "model_10"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_21 (InputLayer)           [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d_778 (Conv2D)             (None, 112, 112, 96) 14112       input_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_509 (BatchN (None, 112, 112, 96) 384         conv2d_778[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_214 (TFOpLambd (None, 112, 112, 96) 0           batch_normalization_509[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_214 (TFOpLambda)   (None, 112, 112, 96) 0           tf.math.softplus_214[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_214 (TFOpLambd (None, 112, 112, 96) 0           batch_normalization_509[0][0]
#                                                                  tf.math.tanh_214[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_87 (MaxPooling2D) (None, 56, 56, 96)   0           tf.math.multiply_214[0][0]
# __________________________________________________________________________________________________
# conv2d_779 (Conv2D)             (None, 56, 56, 16)   1536        max_pooling2d_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_510 (BatchN (None, 56, 56, 16)   64          conv2d_779[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_215 (TFOpLambd (None, 56, 56, 16)   0           batch_normalization_510[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_215 (TFOpLambda)   (None, 56, 56, 16)   0           tf.math.softplus_215[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_215 (TFOpLambd (None, 56, 56, 16)   0           batch_normalization_510[0][0]
#                                                                  tf.math.tanh_215[0][0]
# __________________________________________________________________________________________________
# conv2d_780 (Conv2D)             (None, 56, 56, 64)   1024        tf.math.multiply_215[0][0]
# __________________________________________________________________________________________________
# conv2d_781 (Conv2D)             (None, 56, 56, 64)   9216        tf.math.multiply_215[0][0]
# __________________________________________________________________________________________________
# batch_normalization_511 (BatchN (None, 56, 56, 64)   256         conv2d_780[0][0]
# __________________________________________________________________________________________________
# batch_normalization_512 (BatchN (None, 56, 56, 64)   256         conv2d_781[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_216 (TFOpLambd (None, 56, 56, 64)   0           batch_normalization_511[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_217 (TFOpLambd (None, 56, 56, 64)   0           batch_normalization_512[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_216 (TFOpLambda)   (None, 56, 56, 64)   0           tf.math.softplus_216[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_217 (TFOpLambda)   (None, 56, 56, 64)   0           tf.math.softplus_217[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_216 (TFOpLambd (None, 56, 56, 64)   0           batch_normalization_511[0][0]
#                                                                  tf.math.tanh_216[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_217 (TFOpLambd (None, 56, 56, 64)   0           batch_normalization_512[0][0]
#                                                                  tf.math.tanh_217[0][0]
# __________________________________________________________________________________________________
# concatenate_96 (Concatenate)    (None, 56, 56, 128)  0           tf.math.multiply_216[0][0]
#                                                                  tf.math.multiply_217[0][0]
# __________________________________________________________________________________________________
# conv2d_782 (Conv2D)             (None, 56, 56, 16)   2048        concatenate_96[0][0]
# __________________________________________________________________________________________________
# batch_normalization_513 (BatchN (None, 56, 56, 16)   64          conv2d_782[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_218 (TFOpLambd (None, 56, 56, 16)   0           batch_normalization_513[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_218 (TFOpLambda)   (None, 56, 56, 16)   0           tf.math.softplus_218[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_218 (TFOpLambd (None, 56, 56, 16)   0           batch_normalization_513[0][0]
#                                                                  tf.math.tanh_218[0][0]
# __________________________________________________________________________________________________
# conv2d_783 (Conv2D)             (None, 56, 56, 64)   1024        tf.math.multiply_218[0][0]
# __________________________________________________________________________________________________
# conv2d_784 (Conv2D)             (None, 56, 56, 64)   9216        tf.math.multiply_218[0][0]
# __________________________________________________________________________________________________
# batch_normalization_514 (BatchN (None, 56, 56, 64)   256         conv2d_783[0][0]
# __________________________________________________________________________________________________
# batch_normalization_515 (BatchN (None, 56, 56, 64)   256         conv2d_784[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_219 (TFOpLambd (None, 56, 56, 64)   0           batch_normalization_514[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_220 (TFOpLambd (None, 56, 56, 64)   0           batch_normalization_515[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_219 (TFOpLambda)   (None, 56, 56, 64)   0           tf.math.softplus_219[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_220 (TFOpLambda)   (None, 56, 56, 64)   0           tf.math.softplus_220[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_219 (TFOpLambd (None, 56, 56, 64)   0           batch_normalization_514[0][0]
#                                                                  tf.math.tanh_219[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_220 (TFOpLambd (None, 56, 56, 64)   0           batch_normalization_515[0][0]
#                                                                  tf.math.tanh_220[0][0]
# __________________________________________________________________________________________________
# concatenate_97 (Concatenate)    (None, 56, 56, 128)  0           tf.math.multiply_219[0][0]
#                                                                  tf.math.multiply_220[0][0]
# __________________________________________________________________________________________________
# conv2d_785 (Conv2D)             (None, 56, 56, 32)   4096        concatenate_97[0][0]
# __________________________________________________________________________________________________
# batch_normalization_516 (BatchN (None, 56, 56, 32)   128         conv2d_785[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_221 (TFOpLambd (None, 56, 56, 32)   0           batch_normalization_516[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_221 (TFOpLambda)   (None, 56, 56, 32)   0           tf.math.softplus_221[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_221 (TFOpLambd (None, 56, 56, 32)   0           batch_normalization_516[0][0]
#                                                                  tf.math.tanh_221[0][0]
# __________________________________________________________________________________________________
# conv2d_786 (Conv2D)             (None, 56, 56, 128)  4096        tf.math.multiply_221[0][0]
# __________________________________________________________________________________________________
# conv2d_787 (Conv2D)             (None, 56, 56, 128)  36864       tf.math.multiply_221[0][0]
# __________________________________________________________________________________________________
# batch_normalization_517 (BatchN (None, 56, 56, 128)  512         conv2d_786[0][0]
# __________________________________________________________________________________________________
# batch_normalization_518 (BatchN (None, 56, 56, 128)  512         conv2d_787[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_222 (TFOpLambd (None, 56, 56, 128)  0           batch_normalization_517[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_223 (TFOpLambd (None, 56, 56, 128)  0           batch_normalization_518[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_222 (TFOpLambda)   (None, 56, 56, 128)  0           tf.math.softplus_222[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_223 (TFOpLambda)   (None, 56, 56, 128)  0           tf.math.softplus_223[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_222 (TFOpLambd (None, 56, 56, 128)  0           batch_normalization_517[0][0]
#                                                                  tf.math.tanh_222[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_223 (TFOpLambd (None, 56, 56, 128)  0           batch_normalization_518[0][0]
#                                                                  tf.math.tanh_223[0][0]
# __________________________________________________________________________________________________
# concatenate_98 (Concatenate)    (None, 56, 56, 256)  0           tf.math.multiply_222[0][0]
#                                                                  tf.math.multiply_223[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_88 (MaxPooling2D) (None, 28, 28, 256)  0           concatenate_98[0][0]
# __________________________________________________________________________________________________
# conv2d_788 (Conv2D)             (None, 28, 28, 32)   8192        max_pooling2d_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_519 (BatchN (None, 28, 28, 32)   128         conv2d_788[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_224 (TFOpLambd (None, 28, 28, 32)   0           batch_normalization_519[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_224 (TFOpLambda)   (None, 28, 28, 32)   0           tf.math.softplus_224[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_224 (TFOpLambd (None, 28, 28, 32)   0           batch_normalization_519[0][0]
#                                                                  tf.math.tanh_224[0][0]
# __________________________________________________________________________________________________
# conv2d_789 (Conv2D)             (None, 28, 28, 128)  4096        tf.math.multiply_224[0][0]
# __________________________________________________________________________________________________
# conv2d_790 (Conv2D)             (None, 28, 28, 128)  36864       tf.math.multiply_224[0][0]
# __________________________________________________________________________________________________
# batch_normalization_520 (BatchN (None, 28, 28, 128)  512         conv2d_789[0][0]
# __________________________________________________________________________________________________
# batch_normalization_521 (BatchN (None, 28, 28, 128)  512         conv2d_790[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_225 (TFOpLambd (None, 28, 28, 128)  0           batch_normalization_520[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_226 (TFOpLambd (None, 28, 28, 128)  0           batch_normalization_521[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_225 (TFOpLambda)   (None, 28, 28, 128)  0           tf.math.softplus_225[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_226 (TFOpLambda)   (None, 28, 28, 128)  0           tf.math.softplus_226[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_225 (TFOpLambd (None, 28, 28, 128)  0           batch_normalization_520[0][0]
#                                                                  tf.math.tanh_225[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_226 (TFOpLambd (None, 28, 28, 128)  0           batch_normalization_521[0][0]
#                                                                  tf.math.tanh_226[0][0]
# __________________________________________________________________________________________________
# concatenate_99 (Concatenate)    (None, 28, 28, 256)  0           tf.math.multiply_225[0][0]
#                                                                  tf.math.multiply_226[0][0]
# __________________________________________________________________________________________________
# conv2d_791 (Conv2D)             (None, 28, 28, 48)   12288       concatenate_99[0][0]
# __________________________________________________________________________________________________
# batch_normalization_522 (BatchN (None, 28, 28, 48)   192         conv2d_791[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_227 (TFOpLambd (None, 28, 28, 48)   0           batch_normalization_522[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_227 (TFOpLambda)   (None, 28, 28, 48)   0           tf.math.softplus_227[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_227 (TFOpLambd (None, 28, 28, 48)   0           batch_normalization_522[0][0]
#                                                                  tf.math.tanh_227[0][0]
# __________________________________________________________________________________________________
# conv2d_792 (Conv2D)             (None, 28, 28, 192)  9216        tf.math.multiply_227[0][0]
# __________________________________________________________________________________________________
# conv2d_793 (Conv2D)             (None, 28, 28, 192)  82944       tf.math.multiply_227[0][0]
# __________________________________________________________________________________________________
# batch_normalization_523 (BatchN (None, 28, 28, 192)  768         conv2d_792[0][0]
# __________________________________________________________________________________________________
# batch_normalization_524 (BatchN (None, 28, 28, 192)  768         conv2d_793[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_228 (TFOpLambd (None, 28, 28, 192)  0           batch_normalization_523[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_229 (TFOpLambd (None, 28, 28, 192)  0           batch_normalization_524[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_228 (TFOpLambda)   (None, 28, 28, 192)  0           tf.math.softplus_228[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_229 (TFOpLambda)   (None, 28, 28, 192)  0           tf.math.softplus_229[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_228 (TFOpLambd (None, 28, 28, 192)  0           batch_normalization_523[0][0]
#                                                                  tf.math.tanh_228[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_229 (TFOpLambd (None, 28, 28, 192)  0           batch_normalization_524[0][0]
#                                                                  tf.math.tanh_229[0][0]
# __________________________________________________________________________________________________
# concatenate_100 (Concatenate)   (None, 28, 28, 384)  0           tf.math.multiply_228[0][0]
#                                                                  tf.math.multiply_229[0][0]
# __________________________________________________________________________________________________
# conv2d_794 (Conv2D)             (None, 28, 28, 48)   18432       concatenate_100[0][0]
# __________________________________________________________________________________________________
# batch_normalization_525 (BatchN (None, 28, 28, 48)   192         conv2d_794[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_230 (TFOpLambd (None, 28, 28, 48)   0           batch_normalization_525[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_230 (TFOpLambda)   (None, 28, 28, 48)   0           tf.math.softplus_230[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_230 (TFOpLambd (None, 28, 28, 48)   0           batch_normalization_525[0][0]
#                                                                  tf.math.tanh_230[0][0]
# __________________________________________________________________________________________________
# conv2d_795 (Conv2D)             (None, 28, 28, 192)  9216        tf.math.multiply_230[0][0]
# __________________________________________________________________________________________________
# conv2d_796 (Conv2D)             (None, 28, 28, 192)  82944       tf.math.multiply_230[0][0]
# __________________________________________________________________________________________________
# batch_normalization_526 (BatchN (None, 28, 28, 192)  768         conv2d_795[0][0]
# __________________________________________________________________________________________________
# batch_normalization_527 (BatchN (None, 28, 28, 192)  768         conv2d_796[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_231 (TFOpLambd (None, 28, 28, 192)  0           batch_normalization_526[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_232 (TFOpLambd (None, 28, 28, 192)  0           batch_normalization_527[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_231 (TFOpLambda)   (None, 28, 28, 192)  0           tf.math.softplus_231[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_232 (TFOpLambda)   (None, 28, 28, 192)  0           tf.math.softplus_232[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_231 (TFOpLambd (None, 28, 28, 192)  0           batch_normalization_526[0][0]
#                                                                  tf.math.tanh_231[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_232 (TFOpLambd (None, 28, 28, 192)  0           batch_normalization_527[0][0]
#                                                                  tf.math.tanh_232[0][0]
# __________________________________________________________________________________________________
# concatenate_101 (Concatenate)   (None, 28, 28, 384)  0           tf.math.multiply_231[0][0]
#                                                                  tf.math.multiply_232[0][0]
# __________________________________________________________________________________________________
# conv2d_797 (Conv2D)             (None, 28, 28, 64)   24576       concatenate_101[0][0]
# __________________________________________________________________________________________________
# batch_normalization_528 (BatchN (None, 28, 28, 64)   256         conv2d_797[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_233 (TFOpLambd (None, 28, 28, 64)   0           batch_normalization_528[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_233 (TFOpLambda)   (None, 28, 28, 64)   0           tf.math.softplus_233[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_233 (TFOpLambd (None, 28, 28, 64)   0           batch_normalization_528[0][0]
#                                                                  tf.math.tanh_233[0][0]
# __________________________________________________________________________________________________
# conv2d_798 (Conv2D)             (None, 28, 28, 256)  16384       tf.math.multiply_233[0][0]
# __________________________________________________________________________________________________
# conv2d_799 (Conv2D)             (None, 28, 28, 256)  147456      tf.math.multiply_233[0][0]
# __________________________________________________________________________________________________
# batch_normalization_529 (BatchN (None, 28, 28, 256)  1024        conv2d_798[0][0]
# __________________________________________________________________________________________________
# batch_normalization_530 (BatchN (None, 28, 28, 256)  1024        conv2d_799[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_234 (TFOpLambd (None, 28, 28, 256)  0           batch_normalization_529[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_235 (TFOpLambd (None, 28, 28, 256)  0           batch_normalization_530[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_234 (TFOpLambda)   (None, 28, 28, 256)  0           tf.math.softplus_234[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_235 (TFOpLambda)   (None, 28, 28, 256)  0           tf.math.softplus_235[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_234 (TFOpLambd (None, 28, 28, 256)  0           batch_normalization_529[0][0]
#                                                                  tf.math.tanh_234[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_235 (TFOpLambd (None, 28, 28, 256)  0           batch_normalization_530[0][0]
#                                                                  tf.math.tanh_235[0][0]
# __________________________________________________________________________________________________
# concatenate_102 (Concatenate)   (None, 28, 28, 512)  0           tf.math.multiply_234[0][0]
#                                                                  tf.math.multiply_235[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_89 (MaxPooling2D) (None, 14, 14, 512)  0           concatenate_102[0][0]
# __________________________________________________________________________________________________
# conv2d_800 (Conv2D)             (None, 14, 14, 64)   32768       max_pooling2d_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_531 (BatchN (None, 14, 14, 64)   256         conv2d_800[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_236 (TFOpLambd (None, 14, 14, 64)   0           batch_normalization_531[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_236 (TFOpLambda)   (None, 14, 14, 64)   0           tf.math.softplus_236[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_236 (TFOpLambd (None, 14, 14, 64)   0           batch_normalization_531[0][0]
#                                                                  tf.math.tanh_236[0][0]
# __________________________________________________________________________________________________
# conv2d_801 (Conv2D)             (None, 14, 14, 256)  16384       tf.math.multiply_236[0][0]
# __________________________________________________________________________________________________
# conv2d_802 (Conv2D)             (None, 14, 14, 256)  147456      tf.math.multiply_236[0][0]
# __________________________________________________________________________________________________
# batch_normalization_532 (BatchN (None, 14, 14, 256)  1024        conv2d_801[0][0]
# __________________________________________________________________________________________________
# batch_normalization_533 (BatchN (None, 14, 14, 256)  1024        conv2d_802[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_237 (TFOpLambd (None, 14, 14, 256)  0           batch_normalization_532[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_238 (TFOpLambd (None, 14, 14, 256)  0           batch_normalization_533[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_237 (TFOpLambda)   (None, 14, 14, 256)  0           tf.math.softplus_237[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_238 (TFOpLambda)   (None, 14, 14, 256)  0           tf.math.softplus_238[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_237 (TFOpLambd (None, 14, 14, 256)  0           batch_normalization_532[0][0]
#                                                                  tf.math.tanh_237[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_238 (TFOpLambd (None, 14, 14, 256)  0           batch_normalization_533[0][0]
#                                                                  tf.math.tanh_238[0][0]
# __________________________________________________________________________________________________
# concatenate_103 (Concatenate)   (None, 14, 14, 512)  0           tf.math.multiply_237[0][0]
#                                                                  tf.math.multiply_238[0][0]
# ==================================================================================================
# Total params: 744,352
# Trainable params: 738,400
# Non-trainable params: 5,952
# __________________________________________________________________________________________________

# %% [markdown]
# # InceptionNet
#
# Implement Inception Net by Tensorflow

# %%
import tensorflow as tf
from tensorflow.keras import Input, layers, Model

def inception_block(inputs, filter1, filter3_reduce, filter3, filter5_reduce, filter5, filter_pool, depth=2):
    x1 = layers.Conv2D(filter1, 1, padding='same', activation='relu')(inputs)

    x2 = layers.Conv2D(filter3_reduce, 1, padding='same', activation='relu')(inputs)
    x2 = layers.Conv2D(filter3, 3, padding='same', activation='relu')(x2)

    x3 = layers.Conv2D(filter5_reduce, 1, padding='same', activation='relu')(inputs)
    x3 = layers.Conv2D(filter5, 5, padding='same', activation='relu')(x3)

    x4 = layers.MaxPool2D(3, strides=1, padding='same')(inputs)
    x4 = layers.Conv2D(filter_pool, 1, padding='same', activation='relu')(x4)

    x5 = layers.Concatenate()([x1, x2, x3, x4])

    return x5

def inception_v1(inputs):
    '''Inception
        1. discard dense latyer
        2. network in network: Use conv_1X1 to reduce params and use conv_3X3, conv_5X5 to make [receptive field rich]. Make feature rich.
    '''
    x = layers.Conv2D(64, 7, 2, padding='same', activation='relu')(inputs)
    x = layers.MaxPool2D(3, 2, padding='same')(x)
    x = layers.Conv2D(64, 1, padding='same', activation='relu')(x)
    x = layers.Conv2D(192, 3, padding='same', activation='relu')(x)
    x = layers.MaxPool2D(3, 2, padding='same')(x)

    x1 = inception_block(x, 64, 96, 128, 16, 32, 32)
    x2 = inception_block(x1, 128, 128, 192, 32, 96, 64)
    x3 = layers.MaxPool2D(3, strides=2, padding='same')(x2)
    x4 = inception_block(x3, 192, 96, 208, 16, 48, 64)
    x5 = inception_block(x4, 160, 112, 224, 24, 64, 64)
    x6 = inception_block(x5, 128, 128, 256, 24, 64, 64)
    x7 = inception_block(x6, 112, 144, 288, 32, 64, 64)
    x8 = inception_block(x7, 256, 160, 320, 32, 128, 128)

    x9 = layers.MaxPool2D(3, 2, padding='same')(x8)

    x10 = inception_block(x9, 256, 160, 320, 32, 128, 128)
    x11 = inception_block(x10, 384, 192, 384, 48, 128, 128)

    x12 = layers.AvgPool2D(7, strides=1)(x11)
    x13 = layers.Dropout(rate=0.4)(x12)
    x14 = layers.Dense(1000, activation='softmax')(x13)

    return x14

img_input = Input(shape=(224, 224, 3))

outputs = inception_v1(img_input)

inception = Model(img_input, outputs)

inception.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d_114 (Conv2D)             (None, 112, 112, 64) 9472        input_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_26 (MaxPooling2D) (None, 56, 56, 64)   0           conv2d_114[0][0]
# __________________________________________________________________________________________________
# conv2d_115 (Conv2D)             (None, 56, 56, 64)   4160        max_pooling2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_116 (Conv2D)             (None, 56, 56, 192)  110784      conv2d_115[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_27 (MaxPooling2D) (None, 28, 28, 192)  0           conv2d_116[0][0]
# __________________________________________________________________________________________________
# conv2d_118 (Conv2D)             (None, 28, 28, 96)   18528       max_pooling2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_120 (Conv2D)             (None, 28, 28, 16)   3088        max_pooling2d_27[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_28 (MaxPooling2D) (None, 28, 28, 192)  0           max_pooling2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_117 (Conv2D)             (None, 28, 28, 64)   12352       max_pooling2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_119 (Conv2D)             (None, 28, 28, 128)  110720      conv2d_118[0][0]
# __________________________________________________________________________________________________
# conv2d_121 (Conv2D)             (None, 28, 28, 32)   12832       conv2d_120[0][0]
# __________________________________________________________________________________________________
# conv2d_122 (Conv2D)             (None, 28, 28, 32)   6176        max_pooling2d_28[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 28, 28, 256)  0           conv2d_117[0][0]
#                                                                  conv2d_119[0][0]
#                                                                  conv2d_121[0][0]
#                                                                  conv2d_122[0][0]
# __________________________________________________________________________________________________
# conv2d_124 (Conv2D)             (None, 28, 28, 128)  32896       concatenate_18[0][0]
# __________________________________________________________________________________________________
# conv2d_126 (Conv2D)             (None, 28, 28, 32)   8224        concatenate_18[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_29 (MaxPooling2D) (None, 28, 28, 256)  0           concatenate_18[0][0]
# __________________________________________________________________________________________________
# conv2d_123 (Conv2D)             (None, 28, 28, 128)  32896       concatenate_18[0][0]
# __________________________________________________________________________________________________
# conv2d_125 (Conv2D)             (None, 28, 28, 192)  221376      conv2d_124[0][0]
# __________________________________________________________________________________________________
# conv2d_127 (Conv2D)             (None, 28, 28, 96)   76896       conv2d_126[0][0]
# __________________________________________________________________________________________________
# conv2d_128 (Conv2D)             (None, 28, 28, 64)   16448       max_pooling2d_29[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 28, 28, 480)  0           conv2d_123[0][0]
#                                                                  conv2d_125[0][0]
#                                                                  conv2d_127[0][0]
#                                                                  conv2d_128[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_30 (MaxPooling2D) (None, 14, 14, 480)  0           concatenate_19[0][0]
# __________________________________________________________________________________________________
# conv2d_130 (Conv2D)             (None, 14, 14, 96)   46176       max_pooling2d_30[0][0]
# __________________________________________________________________________________________________
# conv2d_132 (Conv2D)             (None, 14, 14, 16)   7696        max_pooling2d_30[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_31 (MaxPooling2D) (None, 14, 14, 480)  0           max_pooling2d_30[0][0]
# __________________________________________________________________________________________________
# conv2d_129 (Conv2D)             (None, 14, 14, 192)  92352       max_pooling2d_30[0][0]
# __________________________________________________________________________________________________
# conv2d_131 (Conv2D)             (None, 14, 14, 208)  179920      conv2d_130[0][0]
# __________________________________________________________________________________________________
# conv2d_133 (Conv2D)             (None, 14, 14, 48)   19248       conv2d_132[0][0]
# __________________________________________________________________________________________________
# conv2d_134 (Conv2D)             (None, 14, 14, 64)   30784       max_pooling2d_31[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 14, 14, 512)  0           conv2d_129[0][0]
#                                                                  conv2d_131[0][0]
#                                                                  conv2d_133[0][0]
#                                                                  conv2d_134[0][0]
# __________________________________________________________________________________________________
# conv2d_136 (Conv2D)             (None, 14, 14, 112)  57456       concatenate_20[0][0]
# __________________________________________________________________________________________________
# conv2d_138 (Conv2D)             (None, 14, 14, 24)   12312       concatenate_20[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_32 (MaxPooling2D) (None, 14, 14, 512)  0           concatenate_20[0][0]
# __________________________________________________________________________________________________
# conv2d_135 (Conv2D)             (None, 14, 14, 160)  82080       concatenate_20[0][0]
# __________________________________________________________________________________________________
# conv2d_137 (Conv2D)             (None, 14, 14, 224)  226016      conv2d_136[0][0]
# __________________________________________________________________________________________________
# conv2d_139 (Conv2D)             (None, 14, 14, 64)   38464       conv2d_138[0][0]
# __________________________________________________________________________________________________
# conv2d_140 (Conv2D)             (None, 14, 14, 64)   32832       max_pooling2d_32[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 14, 14, 512)  0           conv2d_135[0][0]
#                                                                  conv2d_137[0][0]
#                                                                  conv2d_139[0][0]
#                                                                  conv2d_140[0][0]
# __________________________________________________________________________________________________
# conv2d_142 (Conv2D)             (None, 14, 14, 128)  65664       concatenate_21[0][0]
# __________________________________________________________________________________________________
# conv2d_144 (Conv2D)             (None, 14, 14, 24)   12312       concatenate_21[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_33 (MaxPooling2D) (None, 14, 14, 512)  0           concatenate_21[0][0]
# __________________________________________________________________________________________________
# conv2d_141 (Conv2D)             (None, 14, 14, 128)  65664       concatenate_21[0][0]
# __________________________________________________________________________________________________
# conv2d_143 (Conv2D)             (None, 14, 14, 256)  295168      conv2d_142[0][0]
# __________________________________________________________________________________________________
# conv2d_145 (Conv2D)             (None, 14, 14, 64)   38464       conv2d_144[0][0]
# __________________________________________________________________________________________________
# conv2d_146 (Conv2D)             (None, 14, 14, 64)   32832       max_pooling2d_33[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 14, 14, 512)  0           conv2d_141[0][0]
#                                                                  conv2d_143[0][0]
#                                                                  conv2d_145[0][0]
#                                                                  conv2d_146[0][0]
# __________________________________________________________________________________________________
# conv2d_148 (Conv2D)             (None, 14, 14, 144)  73872       concatenate_22[0][0]
# __________________________________________________________________________________________________
# conv2d_150 (Conv2D)             (None, 14, 14, 32)   16416       concatenate_22[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_34 (MaxPooling2D) (None, 14, 14, 512)  0           concatenate_22[0][0]
# __________________________________________________________________________________________________
# conv2d_147 (Conv2D)             (None, 14, 14, 112)  57456       concatenate_22[0][0]
# __________________________________________________________________________________________________
# conv2d_149 (Conv2D)             (None, 14, 14, 288)  373536      conv2d_148[0][0]
# __________________________________________________________________________________________________
# conv2d_151 (Conv2D)             (None, 14, 14, 64)   51264       conv2d_150[0][0]
# __________________________________________________________________________________________________
# conv2d_152 (Conv2D)             (None, 14, 14, 64)   32832       max_pooling2d_34[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, 14, 14, 528)  0           conv2d_147[0][0]
#                                                                  conv2d_149[0][0]
#                                                                  conv2d_151[0][0]
#                                                                  conv2d_152[0][0]
# __________________________________________________________________________________________________
# conv2d_154 (Conv2D)             (None, 14, 14, 160)  84640       concatenate_23[0][0]
# __________________________________________________________________________________________________
# conv2d_156 (Conv2D)             (None, 14, 14, 32)   16928       concatenate_23[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_35 (MaxPooling2D) (None, 14, 14, 528)  0           concatenate_23[0][0]
# __________________________________________________________________________________________________
# conv2d_153 (Conv2D)             (None, 14, 14, 256)  135424      concatenate_23[0][0]
# __________________________________________________________________________________________________
# conv2d_155 (Conv2D)             (None, 14, 14, 320)  461120      conv2d_154[0][0]
# __________________________________________________________________________________________________
# conv2d_157 (Conv2D)             (None, 14, 14, 128)  102528      conv2d_156[0][0]
# __________________________________________________________________________________________________
# conv2d_158 (Conv2D)             (None, 14, 14, 128)  67712       max_pooling2d_35[0][0]
# __________________________________________________________________________________________________
# concatenate_24 (Concatenate)    (None, 14, 14, 832)  0           conv2d_153[0][0]
#                                                                  conv2d_155[0][0]
#                                                                  conv2d_157[0][0]
#                                                                  conv2d_158[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_36 (MaxPooling2D) (None, 7, 7, 832)    0           concatenate_24[0][0]
# __________________________________________________________________________________________________
# conv2d_160 (Conv2D)             (None, 7, 7, 160)    133280      max_pooling2d_36[0][0]
# __________________________________________________________________________________________________
# conv2d_162 (Conv2D)             (None, 7, 7, 32)     26656       max_pooling2d_36[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_37 (MaxPooling2D) (None, 7, 7, 832)    0           max_pooling2d_36[0][0]
# __________________________________________________________________________________________________
# conv2d_159 (Conv2D)             (None, 7, 7, 256)    213248      max_pooling2d_36[0][0]
# __________________________________________________________________________________________________
# conv2d_161 (Conv2D)             (None, 7, 7, 320)    461120      conv2d_160[0][0]
# __________________________________________________________________________________________________
# conv2d_163 (Conv2D)             (None, 7, 7, 128)    102528      conv2d_162[0][0]
# __________________________________________________________________________________________________
# conv2d_164 (Conv2D)             (None, 7, 7, 128)    106624      max_pooling2d_37[0][0]
# __________________________________________________________________________________________________
# concatenate_25 (Concatenate)    (None, 7, 7, 832)    0           conv2d_159[0][0]
#                                                                  conv2d_161[0][0]
#                                                                  conv2d_163[0][0]
#                                                                  conv2d_164[0][0]
# __________________________________________________________________________________________________
# conv2d_166 (Conv2D)             (None, 7, 7, 192)    159936      concatenate_25[0][0]
# __________________________________________________________________________________________________
# conv2d_168 (Conv2D)             (None, 7, 7, 48)     39984       concatenate_25[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_38 (MaxPooling2D) (None, 7, 7, 832)    0           concatenate_25[0][0]
# __________________________________________________________________________________________________
# conv2d_165 (Conv2D)             (None, 7, 7, 384)    319872      concatenate_25[0][0]
# __________________________________________________________________________________________________
# conv2d_167 (Conv2D)             (None, 7, 7, 384)    663936      conv2d_166[0][0]
# __________________________________________________________________________________________________
# conv2d_169 (Conv2D)             (None, 7, 7, 128)    153728      conv2d_168[0][0]
# __________________________________________________________________________________________________
# conv2d_170 (Conv2D)             (None, 7, 7, 128)    106624      max_pooling2d_38[0][0]
# __________________________________________________________________________________________________
# concatenate_26 (Concatenate)    (None, 7, 7, 1024)   0           conv2d_165[0][0]
#                                                                  conv2d_167[0][0]
#                                                                  conv2d_169[0][0]
#                                                                  conv2d_170[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 1, 1, 1024)   0           concatenate_26[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 1, 1, 1024)   0           average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1, 1, 1000)   1025000     dropout_2[0][0]
# ==================================================================================================
# Total params: 6,998,552
# Trainable params: 6,998,552
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Mobile Net
#
# Implement Mobile net by Tensorflow

# %% [markdown]
# MobileNetV1

# %%
import tensorflow as tf
from tensorflow.keras import Model, layers

class conv_block(Model):
    def __init__(self, filters, kernel_size=(3, 3), strides = 1):
        super().__init__()
        self._filters = filters
        self._kernel_size = kernel_size
        self._strides = strides
    
    def call(self, inputs):
        x = layers.Conv2D(filters=self._filters,kernel_size=self._kernel_size, strides=self._strides, padding='same', use_bias=False)(inputs)
        x = layers.BatchNormalization()(x)
        x = layers.Activation('relu')(x)
        return x

class depthwise_conv_block(Model):
    def __init__(self, pointwise_conv_filters, strides = 1):
        super().__init__()
        self._pointwise_conv_filters = pointwise_conv_filters
        self._strides = strides
    
    def call(self, inputs):
        x = layers.DepthwiseConv2D(kernel_size=(3, 3), strides=self._strides, padding='SAME', use_bias=False)(inputs)
        x =layers.BatchNormalization()(x)
        x = layers.Activation('relu')(x)
        x = layers.Conv2D(filters=self._pointwise_conv_filters, kernel_size=1, padding='same', use_bias=False)(x)
        x = layers.BatchNormalization()(x)
        x = layers.Activation('relu')(x)
        return x

class mobilenet_v1(Model):
    def __init__(self, classes):
        super().__init__()
        self._classes = classes
    
    def build(self, input_shape):
        super(mobilenet_v1, self).build(input_shape)

    def call(self, inputs):
        x = conv_block(32, 2)(inputs)
        x = depthwise_conv_block(64)(x)
        x = depthwise_conv_block(128, strides=(2,2))(x)
        x = depthwise_conv_block(128)(x)
        x = depthwise_conv_block(256, strides=(2,2))(x)
        x = depthwise_conv_block(256)(x)
        x = depthwise_conv_block(512, strides=(2,2))(x)
        x = depthwise_conv_block(512)(x)
        x = depthwise_conv_block(512)(x)
        x = depthwise_conv_block(512)(x)
        x = depthwise_conv_block(512)(x)
        x = depthwise_conv_block(512)(x)
        x = depthwise_conv_block(1024, strides=(2,2))(x)
        x = depthwise_conv_block(1024)(x)
        x = layers.GlobalAveragePooling2D()(x)
        x = layers.Dense(self._classes, activation='softmax')(x)
        return x

# %%
import numpy as np
inputs = np.zeros((10, 32, 32, 3), dtype=np.float32)
model = mobilenet_v1(10)
model.build(input_shape=inputs.shape)
model.summary()
print(inputs.shape)
# Out:
# Model: "mobilenet_v1_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Total params: 0
# Trainable params: 0
# Non-trainable params: 0
# _________________________________________________________________
# (10, 32, 32, 3)
